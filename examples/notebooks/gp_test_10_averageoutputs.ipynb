# %%
import copy
from argparse import Namespace
import numpy as np
import matplotlib.pyplot as plt

from bax.models.simple_gp import SimpleGp
from bax.alg.algorithms import AverageOutputs
from bax.acq.acqoptimize import AcqOptimizer

import neatplot
neatplot.set_style('fonts')

# %%
# Set random seed
seed = 11
np.random.seed(seed)

# %%
# Set function
f = lambda x: 2 * np.sin(x[0])

# Set data for model
data = Namespace()
data.x = [[1.0]]
data.y = [f(x) for x in data.x]

# Set model as a GP
gp_params = {'ls': 2.0, 'alpha': 2.0, 'sigma': 1e-2}
model = SimpleGp(gp_params)
model.set_data(data)

# Set arrays
min_x = 3.5
max_x = 20.0
len_path = 15
x_rand = np.random.uniform(min_x, max_x, len_path)
x_path = [[x] for x in x_rand]
x_path_big = [[x] for x in np.linspace(0.0, max_x, 200)]
x_test = [[x] for x in np.linspace(0.0, max_x, 500)]

# Set algorithm
algo = AverageOutputs({'x_path': x_path})

# Set "true execution path"
exe_path_true = Namespace(x=x_path_big, y=[f(x) for x in x_path_big])
# Out:
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AverageOutputs with params=Namespace(name='AverageOutputs')

# %%
# BAX iterations

n_iter = 40

for i in range(n_iter):
    # Plot setup
    fig = plt.figure(figsize=(8, 5))
    plt.xlim([0, max_x + 1])
    plt.ylim([-7.0, 7.0])
    plt.xlabel('x')
    plt.ylabel('y')

    # Optimize acquisition function
    acqopt = AcqOptimizer({'x_test': x_test})
    x_next = acqopt.optimize(model, algo)
    print(f'Acq optimizer x_next = {x_next}')
    print(f'Finished iter i = {i}')

    # Plot true execution path
    plt.plot(exe_path_true.x, exe_path_true.y, '-', color='k', linewidth=3)

    # Show plot
    neatplot.save_figure(f'gp_test_10_{i}')
    plt.show()

    inp = input('Press enter to continue (any other key to stop): ')
    if inp:
        break
    plt.close()

    # Query function, update data
    y_next = f(x_next)
    data.x.append(x_next)
    data.y.append(y_next)

    # Update model
    model = SimpleGp(gp_params)
    model.set_data(data)
# Out:
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.54 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.65 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [11.422845691382765]
# Finished iter i = 0
# Saved figure gp_test_10_0.pdf
# Saved figure gp_test_10_0.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.57 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.60 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [17.675350701402806]
# Finished iter i = 1
# Saved figure gp_test_10_1.pdf
# Saved figure gp_test_10_1.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.55 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.64 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [6.372745490981964]
# Finished iter i = 2
# Saved figure gp_test_10_2.pdf
# Saved figure gp_test_10_2.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.59 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.63 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [3.7675350701402803]
# Finished iter i = 3
# Saved figure gp_test_10_3.pdf
# Saved figure gp_test_10_3.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.59 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.63 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [15.511022044088175]
# Finished iter i = 4
# Saved figure gp_test_10_4.pdf
# Saved figure gp_test_10_4.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.61 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.63 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [18.997995991983966]
# Finished iter i = 5
# Saved figure gp_test_10_5.pdf
# Saved figure gp_test_10_5.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.61 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.63 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [10.460921843687375]
# Finished iter i = 6
# Saved figure gp_test_10_6.pdf
# Saved figure gp_test_10_6.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.68 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.65 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [5.33066132264529]
# Finished iter i = 7
# Saved figure gp_test_10_7.pdf
# Saved figure gp_test_10_7.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.64 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.65 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [18.236472945891784]
# Finished iter i = 8
# Saved figure gp_test_10_8.pdf
# Saved figure gp_test_10_8.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.65 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.69 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [11.703406813627254]
# Finished iter i = 9
# Saved figure gp_test_10_9.pdf
# Saved figure gp_test_10_9.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.67 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.68 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [5.891783567134269]
# Finished iter i = 10
# Saved figure gp_test_10_10.pdf
# Saved figure gp_test_10_10.png
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x118bf5200>, ls=2.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.68 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.66 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [17.51503006012024]
# Finished iter i = 11
# Saved figure gp_test_10_11.pdf
# Saved figure gp_test_10_11.png
# Press enter to continue (any other key to stop): bye
