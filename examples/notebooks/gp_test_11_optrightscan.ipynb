# %%
import copy
from argparse import Namespace
import numpy as np
import matplotlib.pyplot as plt

from bax.models.simple_gp import SimpleGp
from bax.alg.algorithms import OptRightScan
from bax.acq.acqoptimize import AcqOptimizer

import neatplot
neatplot.set_style('fonts')

# %%
# Set random seed
seed = 11
np.random.seed(seed)

# %%
# Set function
xm = 0.3
xa = 4.0
ym = 2.0
f = lambda x: ym * np.sin(np.pi * xm * (x[0] + xa)) + \
              ym * np.sin(2 * xm * np.pi * (x[0] + xa)) / 2.0

# Set data for model
data = Namespace()
data.x = [[4.0]]
data.y = [f(x) for x in data.x]

# Set model as a GP
gp_params = {'ls': 1.0, 'alpha': 2.0, 'sigma': 1e-2}
model = SimpleGp(gp_params)
model.set_data(data)

# Set arrays
min_x = 3.5
max_x = 20.0
x_path_big = [[x] for x in np.linspace(3.8, 8.0, 200)]
x_test = [[x] for x in np.linspace(0.0, max_x, 500)]
y_test = [f(x) for x in x_test]

# Set algorithm
algo = OptRightScan({'x_grid_gap': 0.1})
# Out:
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] OptRightScan with params=Namespace(conv_thresh=0.2, init_x=[4.0], max_iter=100, name='OptRightScan', x_grid_gap=0.1)

# %%
# BAX iterations

n_iter = 40

for i in range(n_iter):
    # Plot setup
    fig = plt.figure(figsize=(8, 5))
    plt.xlim([0, max_x + 1])
    plt.ylim([-7.0, 8.0])
    plt.xlabel('x')
    plt.ylabel('y')

    # Optimize acquisition function
    acqopt = AcqOptimizer({'x_test': x_test})
    x_next = acqopt.optimize(model, algo)
    print(f'Acq optimizer x_next = {x_next}')
    print(f'Finished iter i = {i}')

    # Plot true function
    plt.plot(x_test, y_test, '-', color='k', linewidth=2)

    # Show plot
    # neatplot.save_figure(f'gp_test_11_{i}')
    plt.show()

    inp = input('Press enter to continue (any other key to stop): ')
    if inp:
        break
    plt.close()

    # Query function, update data
    y_next = f(x_next)
    data.x.append(x_next)
    data.y.append(y_next)

    # Update model
    model = SimpleGp(gp_params)
    model.set_data(data)
# Out:
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 0.76 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.70 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [4.529058116232465]
# Finished iter i = 0
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 1.19 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.62 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [5.571142284569138]
# Finished iter i = 1
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 1.42 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.65 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [6.132264529058116]
# Finished iter i = 2
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 1.85 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.69 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [6.933867735470941]
# Finished iter i = 3
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 2.51 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.71 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [7.695390781563126]
# Finished iter i = 4
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 2.78 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.76 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [8.296593186372744]
# Finished iter i = 5
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 2.90 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.78 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [8.617234468937875]
# Finished iter i = 6
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10b127200>, ls=1.0, sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(n_path=100, name='AcqOptimizer', opt_str='rs', viz_acq=True)
# *[TIME] [Sample 100 execution paths] Elapsed: 2.91 seconds
# *[TIME] [Pre-compute acquisition at 500 test points] Elapsed: 0.74 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='pe', name='AcqFunction')
# Acq optimizer x_next = [5.01002004008016]
# Finished iter i = 7
# Press enter to continue (any other key to stop): bye
