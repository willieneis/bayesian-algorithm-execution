# %%
import copy
from argparse import Namespace
import numpy as np
import matplotlib.pyplot as plt
#plt.ion()

from bax.models.simple_gp import SimpleGp
from bax.alg.evolution_strategies import EvolutionStrategies
from bax.acq.acqoptimize import AcqOptimizer

from examples.es.branin import branin, unif_random_sample_domain

import neatplot
neatplot.set_style('fonts')
neatplot.update_rc('figure.dpi', 80)

# %%
# Set random seed
seed = 11
np.random.seed(seed)

# %%
# Set function
f = lambda x: -1 * branin(x)
domain = [[-5, 10], [0, 15]]
init_x = [4.0, 14.0]
#init_x = [7.0, 15.0]
#init_x = [0.0, 0.0]

# Set data for model
data = Namespace()
data.x = [init_x]
data.y = [f(x) for x in data.x]

# Set model as a GP
gp_params = {'ls': 3.0, 'alpha': 2.0, 'sigma': 1e-2}
model = SimpleGp(gp_params)
model.set_data(data)

# Set algorithm
algo = EvolutionStrategies(
    {'n_generation': 15, 'n_population': 8, 'samp_str': 'mut', 'init_x': init_x}
) # Code currently requires init to 0
# Out:
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] EvolutionStrategies with params=Namespace(init_x=[4.0, 14.0], n_dim=2, n_dim_es=2, n_generation=15, n_population=8, name='EvolutionStrategies', samp_str='mut')

# %%
n_iter = 25

for i in range(n_iter):

    # Plot setup
    fig = plt.figure(figsize=(6, 6))
    plt.xlim([-5, 10])
    plt.ylim([0, 15])
    plt.xlabel('x')
    plt.ylabel('y')

    im = plt.imread('../es/branin_contour.png')
    implot = plt.imshow(im, extent=[domain[0][0], domain[0][1], domain[1][0], domain[1][1]])

    # Optimize acquisition function
    x_test = unif_random_sample_domain(domain, n=150)
    acqopt = AcqOptimizer(
        {
            'x_test': x_test,
            'acq_str': 'out',
            'n_path': 20,
            'viz_acq': True,
            'viz_dim': 2,
        }
    )
    x_next = acqopt.optimize(model, algo)

    # Update algo.init_x
    algo.params.init_x = data.x[np.argmax(data.y)]

    # Compute current expected output
    expected_output = np.mean(acqopt.get_last_output_list(), 0)

    # Query function, update data
    y_next = f(x_next)
    data.x.append(x_next)
    data.y.append(y_next)

    # Print
    print(f'Acq optimizer x_next = {x_next}')
    print(f'Current expected_output = {expected_output}')
    f_expected_output = f(expected_output)
    print(f'Current expected value f(expected_output) = {f_expected_output}')
    print(f'Finished iter i = {i}')

    # Show plot
    plt.show()

    inp = input('Press enter to continue (any other key to stop): ')
    if inp:
        break

    # Update model
    model = SimpleGp(gp_params)
    model.set_data(data)
# Out:
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.60 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.07 seconds
# Acq optimizer x_next = [4.720846629637203, 14.062562765591473]
# Current expected_output = [ 4.64447366 12.95344881]
# Current expected value f(expected_output) = -142.95195457278857
# Finished iter i = 0
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.33 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.21 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.07 seconds
# Acq optimizer x_next = [1.9040096596100193, 12.124332922300475]
# Current expected_output = [-2.77879488 12.96419912]
# Current expected value f(expected_output) = -3.4071123820784095
# Finished iter i = 1
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.80 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.07 seconds
# Acq optimizer x_next = [1.1699442779128555, 14.803708433022155]
# Current expected_output = [-2.50792442 17.40223854]
# Current expected value f(expected_output) = -45.7985791946128
# Finished iter i = 2
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.83 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.05 seconds
# Acq optimizer x_next = [1.7286685974620415, 7.850911816387642]
# Current expected_output = [0.90499156 5.73253775]
# Current expected value f(expected_output) = -17.069795418207445
# Finished iter i = 3
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.81 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.12 seconds
# Acq optimizer x_next = [1.3110002836095873, 9.521148099343803]
# Current expected_output = [0.99688274 4.88249196]
# Current expected value f(expected_output) = -15.329281856681451
# Finished iter i = 4
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.90 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.07 seconds
# Acq optimizer x_next = [2.3155977891324167, 4.957912186462325]
# Current expected_output = [2.77994024 1.65510546]
# Current expected value f(expected_output) = -1.863261434982439
# Finished iter i = 5
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.83 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [1.0667484160689895, 4.980039326094297]
# Current expected_output = [3.35708525 1.86048344]
# Current expected value f(expected_output) = -0.6837097467689155
# Finished iter i = 6
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.01 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.24 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.05 seconds
# Acq optimizer x_next = [5.665839135688083, 3.9059662055358606]
# Current expected_output = [5.30498973 3.65270002]
# Current expected value f(expected_output) = -21.415679108127286
# Finished iter i = 7
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.13 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [2.4641800578962183, 3.1901414169850106]
# Current expected_output = [2.05711507 1.62245475]
# Current expected value f(expected_output) = -8.235435458693495
# Finished iter i = 8
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 3.90 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [1.83781855412236, 1.688717633720474]
# Current expected_output = [1.41438257 0.10323842]
# Current expected value f(expected_output) = -26.738037063072397
# Finished iter i = 9
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.32 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.22 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [3.514351377055341, 2.384615377376653]
# Current expected_output = [2.7529476  3.13504422]
# Current expected value f(expected_output) = -1.4028258992437408
# Finished iter i = 10
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.10 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.05 seconds
# Acq optimizer x_next = [4.684068281347624, 3.1718860204658745]
# Current expected_output = [3.19689305 2.79448555]
# Current expected value f(expected_output) = -0.7286538542911689
# Finished iter i = 11
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.25 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [4.227644136428417, 0.6080709705214377]
# Current expected_output = [4.08883405 0.46799797]
# Current expected value f(expected_output) = -5.795418271404238
# Finished iter i = 12
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.58 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.24 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.05 seconds
# Acq optimizer x_next = [3.576872624341693, 3.386177643960853]
# Current expected_output = [3.17345152 2.46077248]
# Current expected value f(expected_output) = -0.44706464822356473
# Finished iter i = 13
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.49 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.06 seconds
# Acq optimizer x_next = [2.210725177883891, 1.279074867971513]
# Current expected_output = [3.5359072  2.23008821]
# Current expected value f(expected_output) = -1.1935644131067136
# Finished iter i = 14
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.60 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.23 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.12 seconds
# Acq optimizer x_next = [2.756156175979932, 2.514849678246418]
# Current expected_output = [2.95432304 2.35542039]
# Current expected value f(expected_output) = -0.5706900650473763
# Finished iter i = 15
# Press enter to continue (any other key to stop):
# *[INFO] SimpleGp with params=Namespace(alpha=2.0, kernel=<function kern_exp_quad at 0x10af5c200>, ls=3.0, name='SimpleGp', sigma=0.01)
# *[INFO] AcqOptimizer with params=Namespace(acq_str='out', n_path=20, name='AcqOptimizer', opt_str='rs', viz_acq=True, viz_dim=2)
# *[TIME] [Sample 20 execution paths] Elapsed: 4.46 seconds
# *[INFO] AcqFunction with params=Namespace(acq_str='out', n_cluster_kmeans=35, name='AcqFunction')
# *[TIME] [Compute acquisition function at 150 test points] Elapsed: 0.24 seconds
# *[TIME] [Visualize acquisition function] Elapsed: 0.05 seconds
# Acq optimizer x_next = [3.812918264242448, 1.6506881920501764]
# Current expected_output = [3.15830858 2.34610769]
# Current expected value f(expected_output) = -0.40630294529711364
# Finished iter i = 16
# Press enter to continue (any other key to stop): bye
